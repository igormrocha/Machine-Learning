# %%
import tensorflow as tf
import keras
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
(X_train, y_train),(X_test, y_test) = keras.datasets.mnist.load_data()

# %%
plt.imshow(X_train[3], cmap = 'gray')

# %%
X_train = X_train/255
X_test = X_test/255

# %%
X_train_flattened = X_train.reshape(len(X_train),28*28)
X_test_flattened = X_test.reshape(len(X_test),28*28)

# %%
model = keras.Sequential([
    keras.layers.Dense(10, input_shape=(784,), activation = 'sigmoid')
])

model.compile(optimizer='adam', 
              loss = 'sparse_categorical_crossentropy',
              metrics = ['accuracy'])

model.fit(X_train_flattened, y_train, epochs = 5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4928 - accuracy: 0.8735
# Epoch 2/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3065 - accuracy: 0.9157
# Epoch 3/5
# 1875/1875 [==============================] - 2s 845us/step - loss: 0.2852 - accuracy: 0.9208
# Epoch 4/5
# 1875/1875 [==============================] - 2s 987us/step - loss: 0.2745 - accuracy: 0.9238
# Epoch 5/5
# 1875/1875 [==============================] - 2s 840us/step - loss: 0.2676 - accuracy: 0.9260

# %%
model.evaluate(X_test_flattened, y_test)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.2640 - accuracy: 0.9276
# [0.2640267610549927, 0.9276000261306763]

# %%
y_predicted = np.argmax(model.predict(X_test_flattened), axis = -1)
y_predicted
# Out:
# array([7, 2, 1, ..., 4, 5, 6])

# %%
cm = tf.math.confusion_matrix(labels=y_test, predictions=y_predicted)
cm
# Out:
# <tf.Tensor: shape=(10, 10), dtype=int32, numpy=
# array([[ 958,    0,    1,    2,    0,    6,    9,    2,    2,    0],
#        [   0, 1110,    3,    2,    0,    1,    4,    2,   13,    0],
#        [   5,    8,  925,   15,    6,    5,   13,   10,   41,    4],
#        [   3,    0,   19,  918,    0,   25,    2,   12,   24,    7],
#        [   1,    1,    4,    1,  907,    0,   16,    4,   10,   38],
#        [   7,    2,    2,   26,    6,  794,   17,    4,   27,    7],
#        [   8,    3,    4,    1,    7,   10,  922,    1,    2,    0],
#        [   1,    6,   24,    4,    6,    0,    0,  956,    1,   30],
#        [   7,    6,    6,   17,    8,   34,   11,   11,  869,    5],
#        [  10,    7,    1,    9,   24,    9,    0,   25,    7,  917]],
#       dtype=int32)>

# %%
import seaborn as sns
plt.figure(figsize=(10,7))
sns.heatmap(cm, annot = True, fmt = 'd')
# Out:
# <AxesSubplot:>

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(50, input_dim=784,activation = 'relu'))
model.add(keras.layers.Dense(10, activation = 'sigmoid'))

model.compile(optimizer='adam', 
              loss = 'sparse_categorical_crossentropy',
              metrics = ['accuracy'])

model.fit(X_train_flattened, y_train, epochs = 5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-79bcebbf036a> in <module>
# ----> 1 model = keras.Sequential()
#       2 model.add(keras.layers.Dense(50, input_dim=784,activation = 'relu'))
#       3 model.add(keras.layers.Dense(10, activation = 'sigmoid'))
#       4
#       5 model.compile(optimizer='adam',
#
# NameError: name 'keras' is not defined

# %%
model.compile(optimizer='adam', 
              loss = 'sparse_categorical_crossentropy',
              metrics = ['accuracy'])

model.fit(X_train_flattened, y_train, epochs = 5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0810 - accuracy: 0.9760
# Epoch 2/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0702 - accuracy: 0.9791
# Epoch 3/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0635 - accuracy: 0.9805
# Epoch 4/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0576 - accuracy: 0.9824
# Epoch 5/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0516 - accuracy: 0.9841

# %%
y_predicted = np.argmax(model.predict(X_test_flattened), axis = -1)
y_predicted

cm = tf.math.confusion_matrix(labels=y_test, predictions=y_predicted)
cm

import seaborn as sns
plt.figure(figsize=(10,7))
sns.heatmap(cm, annot = True, fmt = 'd')
# Out:
# <AxesSubplot:>
